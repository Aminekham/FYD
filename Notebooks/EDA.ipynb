# %% [markdown]
# # Elbow method on resumes

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("processed_resumes_data.csv")
data['Extracted Text'].fillna('', inplace=True)

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Extracted Text'])

wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(tfidf_matrix)
    wcss.append(kmeans.inertia_)

wcss = np.array(wcss)
wcss_normalized = (wcss - wcss.min()) / (wcss.max() - wcss.min())

# %%
plt.plot(range(1, 20), wcss_normalized, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Normalized WCSS')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("processed_resumes_data.csv")
data['Extracted Text'].fillna('', inplace=True)
count_vectorizer = CountVectorizer()
bow_matrix = count_vectorizer.fit_transform(data['Extracted Text'])

wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(bow_matrix)
    wcss.append(kmeans.inertia_)

wcss = np.array(wcss)
wcss_normalized = (wcss - wcss.min()) / (wcss.max() - wcss.min())

# %%
# Plot the elbow method graph
plt.plot(range(1, 20), wcss_normalized)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # Elbow method on jobs

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("output.csv")
data['Job_Description'].fillna('', inplace=True)
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Job_Description'])

wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(tfidf_matrix)
    wcss.append(kmeans.inertia_)

wcss = np.array(wcss)
wcss_normalized = (wcss - wcss.min()) / (wcss.max() - wcss.min())

# %%
plt.plot(range(1, 20), wcss_normalized, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Normalized WCSS')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("output.csv")
data['Job_Description'].fillna('', inplace=True)
count_vectorizer = CountVectorizer()
bow_matrix = count_vectorizer.fit_transform(data['Job_Description'])

wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(bow_matrix)
    wcss.append(kmeans.inertia_)

wcss = np.array(wcss)
wcss_normalized = (wcss - wcss.min()) / (wcss.max() - wcss.min())

# %%
plt.plot(range(1, 20), wcss_normalized, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Normalized WCSS')
plt.grid(True)
plt.show()
